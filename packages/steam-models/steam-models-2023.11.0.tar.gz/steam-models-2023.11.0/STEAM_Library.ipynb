# %%
# Install required package
import sys
# !{sys.executable} -m pip install --user --upgrade steam-sdk

import os
import numpy as np
from matplotlib import pyplot as plt 
import ipywidgets as widgets

# Import local GUI settings/functions
from GUI_settings import *

# Set matplotlib mode
# %matplotlib widget
# Out:
# INFO:SparkMonitorKernel:SparkMonitor comm opened from frontend.
# Collecting steam-sdk
#   Downloading steam_sdk-0.0.142-py3-none-any.whl (342 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.6/342.6 KB 10.2 MB/s eta 0:00:00
# Collecting smmap==5.0.0
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting parso==0.8.3
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 KB 35.0 MB/s eta 0:00:00
# Collecting kiwisolver==1.4.4
#   Downloading kiwisolver-1.4.4-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.0 MB/s eta 0:00:00
# Collecting tqdm==4.64.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 27.4 MB/s eta 0:00:00
# Collecting pymdown-extensions==9.5
#   Downloading pymdown_extensions-9.5-py3-none-any.whl (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.5/217.5 KB 58.8 MB/s eta 0:00:00
# Collecting click==8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 38.0 MB/s eta 0:00:00
# Collecting charset-normalizer==2.1.1
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting Jinja2==3.1.2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 37.3 MB/s eta 0:00:00
# Collecting ordered-set==4.1.0
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting mkdocstrings-python==0.7.1
#   Downloading mkdocstrings_python-0.7.1-py3-none-any.whl (37 kB)
# Collecting pyparsing==3.0.9
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 KB 37.3 MB/s eta 0:00:00
# Collecting mkdocs==1.3.1
#   Downloading mkdocs-1.3.1-py3-none-any.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 126.4 MB/s eta 0:00:00
# Collecting scipy==1.9.1
#   Downloading scipy-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 48.5 MB/s eta 0:00:0000:0100:01
# Collecting gitdb==4.0.9
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 KB 20.2 MB/s eta 0:00:00
# Collecting STEAM-materials==0.0.2
#   Downloading STEAM_materials-0.0.2-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 109.2 MB/s eta 0:00:00
# Collecting ruamel.yaml==0.17.21
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 43.0 MB/s eta 0:00:00
# Collecting mkdocs-material-extensions==1.0.3
#   Downloading mkdocs_material_extensions-1.0.3-py3-none-any.whl (8.1 kB)
# Collecting prompt-toolkit==3.0.31
#   Downloading prompt_toolkit-3.0.31-py3-none-any.whl (382 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.3/382.3 KB 84.4 MB/s eta 0:00:00
# Collecting GitPython==3.1.27
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 KB 52.7 MB/s eta 0:00:00
# Collecting cycler==0.11.0
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting matplotlib-inline==0.1.6
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting Pygments==2.13.0
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 140.9 MB/s eta 0:00:00
# Collecting asttokens==2.0.8
#   Downloading asttokens-2.0.8-py2.py3-none-any.whl (23 kB)
# Collecting deepdiff==5.8.1
#   Downloading deepdiff-5.8.1-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 KB 19.0 MB/s eta 0:00:00
# Collecting mkdocs-include-markdown-plugin==3.8.1
#   Downloading mkdocs_include_markdown_plugin-3.8.1-py3-none-any.whl (17 kB)
# Collecting ruamel.yaml.clib==0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp39-cp39-manylinux1_x86_64.whl (539 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.7/539.7 KB 95.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil==2.8.2 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (2.8.2)
# Requirement already satisfied: pytest-cov==3.0.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (3.0.0)
# Collecting seaborn==0.12.0
#   Downloading seaborn-0.12.0-py3-none-any.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.1/285.1 KB 75.4 MB/s eta 0:00:00
# Collecting decorator==5.1.1
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting gmsh==4.10.5
#   Downloading gmsh-4.10.5-py2.py3-none-manylinux1_x86_64.whl (38.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 62.1 MB/s eta 0:00:0000:0100:01
# Collecting executing==1.0.0
#   Downloading executing-1.0.0-py2.py3-none-any.whl (16 kB)
# Collecting pytz==2022.2.1
#   Downloading pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.6/500.6 KB 94.0 MB/s eta 0:00:00
# Collecting matplotlib==3.6.0
#   Downloading matplotlib-3.6.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 64.8 MB/s eta 0:00:0000:010:01m
# Collecting mkdocs-autorefs==0.4.1
#   Downloading mkdocs_autorefs-0.4.1-py3-none-any.whl (9.8 kB)
# Collecting watchdog==2.1.9
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 23.0 MB/s eta 0:00:00
# Collecting MarkupSafe==2.1.1
#   Downloading MarkupSafe-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting py==1.11.0
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 KB 37.2 MB/s eta 0:00:00
# Collecting pluggy==1.0.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting pyyaml-env-tag==0.1
#   Downloading pyyaml_env_tag-0.1-py3-none-any.whl (3.9 kB)
# Collecting contourpy==1.0.5
#   Downloading contourpy-1.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 KB 56.3 MB/s eta 0:00:00
# Collecting typing-extensions==4.3.0
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting stack-data==0.5.0
#   Downloading stack_data-0.5.0-py3-none-any.whl (24 kB)
# Collecting traitlets==5.4.0
#   Downloading traitlets-5.4.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.1/107.1 KB 39.0 MB/s eta 0:00:00
# Collecting zipp==3.8.1
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: backcall==0.2.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (0.2.0)
# Collecting coverage-badge==1.1.0
#   Downloading coverage_badge-1.1.0-py2.py3-none-any.whl (6.4 kB)
# Collecting idna==3.4
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 KB 24.6 MB/s eta 0:00:00
# Collecting packaging==21.3
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 KB 10.5 MB/s eta 0:00:00
# Collecting openpyxl==3.0.10
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 74.1 MB/s eta 0:00:00
# Collecting PyYAML==6.0
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 KB 85.2 MB/s eta 0:00:00
# Collecting coverage==6.4.4
#   Downloading coverage-6.4.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 KB 46.1 MB/s eta 0:00:00
# Collecting iniconfig==1.1.1
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: et-xmlfile==1.1.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (1.1.0)
# Collecting Babel==2.10.3
#   Downloading Babel-2.10.3-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 124.4 MB/s eta 0:00:0000:0100:01
# Collecting importlib-metadata==4.12.0
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting pysoleno==0.0.8
#   Downloading pysoleno-0.0.8-py3-none-any.whl (5.4 kB)
# Collecting colorama==0.4.5
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: wcwidth==0.2.5 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (0.2.5)
# Collecting pure-eval==0.2.2
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting Markdown==3.3.7
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 KB 27.2 MB/s eta 0:00:00
# Collecting numpy==1.23.3
#   Downloading numpy-1.23.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 76.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six==1.16.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (1.16.0)
# Collecting mkdocs-git-revision-date-localized-plugin==1.1.0
#   Downloading mkdocs_git_revision_date_localized_plugin-1.1.0-py3-none-any.whl (21 kB)
# Collecting attrs==22.1.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 23.1 MB/s eta 0:00:00
# Collecting mergedeep==1.3.4
#   Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Collecting jedi==0.18.1
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 150.5 MB/s eta 0:00:00
# Requirement already satisfied: tomli==2.0.1 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (2.0.1)
# Collecting ghp-import==2.1.0
#   Downloading ghp_import-2.1.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pickleshare==0.7.5 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from steam-sdk) (0.7.5)
# Collecting requests==2.28.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 22.7 MB/s eta 0:00:00
# Collecting mkdocstrings==0.19.0
#   Downloading mkdocstrings-0.19.0-py3-none-any.whl (25 kB)
# Collecting h5py==3.7.0
#   Downloading h5py-3.7.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 90.8 MB/s eta 0:00:00ta 0:00:01
# Collecting ipython==8.5.0
#   Downloading ipython-8.5.0-py3-none-any.whl (752 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 752.0/752.0 KB 110.4 MB/s eta 0:00:00
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 KB 64.2 MB/s eta 0:00:00
# Collecting markdown-include==0.7.0
#   Downloading markdown_include-0.7.0-py3-none-any.whl (16 kB)
# Collecting pydantic==1.10.2
#   Downloading pydantic-1.10.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 100.0 MB/s eta 0:00:0000:0100:01
# Collecting urllib3==1.26.12
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 KB 49.8 MB/s eta 0:00:00
# Collecting griffe==0.22.1
#   Downloading griffe-0.22.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 12.2 MB/s eta 0:00:00
# Collecting pytest==7.1.3
#   Downloading pytest-7.1.3-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 KB 64.6 MB/s eta 0:00:00
# Collecting fonttools==4.37.3
#   Downloading fonttools-4.37.3-py3-none-any.whl (959 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.0/960.0 KB 131.6 MB/s eta 0:00:00
# Collecting pandas==1.5.0
#   Downloading pandas-1.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 101.1 MB/s eta 0:00:0000:0100:01
# Collecting mkdocs-material==8.5.3
#   Downloading mkdocs_material-8.5.3-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 115.9 MB/s eta 0:00:00a 0:00:01
# Collecting certifi==2022.9.14
#   Downloading certifi-2022.9.14-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 KB 57.6 MB/s eta 0:00:00
# Collecting npTDMS==1.6.0
#   Downloading npTDMS-1.6.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 KB 58.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting Pillow==9.2.0
#   Downloading Pillow-9.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.6 MB/s eta 0:00:00:00:01
# Requirement already satisfied: pexpect>4.3 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from ipython==8.5.0->steam-sdk) (4.8.0)
# Requirement already satisfied: coverage[toml]>=5.2.1 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from pytest-cov==3.0.0->steam-sdk) (6.3.2)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.0.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 KB 78.0 MB/s eta 0:00:00
#   Downloading coverage-7.0.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.3/224.3 KB 75.0 MB/s eta 0:00:00
#   Downloading coverage-7.0.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 KB 72.0 MB/s eta 0:00:00
#   Downloading coverage-7.0.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 KB 55.7 MB/s eta 0:00:00
#   Downloading coverage-7.0.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 KB 73.1 MB/s eta 0:00:00
#   Downloading coverage-6.5.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 KB 76.8 MB/s eta 0:00:00
# Building wheels for collected packages: npTDMS
#   Building wheel for npTDMS (setup.py) ... done
#   Created wheel for npTDMS: filename=npTDMS-1.6.0-py3-none-any.whl size=103813 sha256=cd85cbce820c47c3ee92aebe8b8988c0cac597cedcb6129aec5a93ff28d9dba4
#   Stored in directory: /tmp/emm/.cache/pip/wheels/cb/68/e1/458e52e758690e8f8f46679958fd0dc55e3d49378b623dc995
# Successfully built npTDMS
# Installing collected packages: pytz, py4j, pure-eval, iniconfig, gmsh, executing, zipp, watchdog, urllib3, typing-extensions, traitlets, tqdm, smmap, ruamel.yaml.clib, PyYAML, pyparsing, Pygments, py, prompt-toolkit, pluggy, Pillow, parso, ordered-set, openpyxl, numpy, mkdocs-material-extensions, mkdocs-include-markdown-plugin, mergedeep, MarkupSafe, kiwisolver, idna, griffe, fonttools, decorator, cycler, coverage, colorama, click, charset-normalizer, certifi, Babel, attrs, asttokens, STEAM-materials, stack-data, scipy, ruamel.yaml, requests, pyyaml-env-tag, pysoleno, pydantic, pandas, packaging, npTDMS, matplotlib-inline, Jinja2, jedi, importlib-metadata, h5py, gitdb, ghp-import, deepdiff, coverage-badge, contourpy, pytest, matplotlib, Markdown, ipython, GitPython, seaborn, pymdown-extensions, mkdocs, markdown-include, mkdocs-material, mkdocs-git-revision-date-localized-plugin, mkdocs-autorefs, mkdocstrings, mkdocstrings-python, steam-sdk
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/eos/user/e/emm'
# Check the permissions.
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-54kocdf7 because the default path (/eos/user/e/emm/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_653/3372197950.py in <module>
#       9
#      10 # Import local GUI settings/functions
# ---> 11 from GUI_settings import *
#      12
#      13 # Set matplotlib mode
#
# ModuleNotFoundError: No module named 'GUI_settings'

# %%
# STEAM Library GUI
cases = ['magnet', 'circuit']
list_subfolders_magnets = next(os.walk('magnets'))[1]  # List all subfolders
list_subfolders_magnets = [x for x in list_subfolders_magnets if not ".sys" in x]  # Remove entries with ".sys"
list_subfolders_magnets = [x for x in list_subfolders_magnets if not "__pycache__" in x]  # Remove entries with "__pycache__"

list_subfolders_circuits = next(os.walk('circuits'))[1]  # List all subfolders
list_subfolders_circuits = [x for x in list_subfolders_circuits if not ".sys" in x]  # Remove entries with ".sys"
list_subfolders_circuits = [x for x in list_subfolders_circuits if not "__pycache__" in x]  # Remove entries with "__pycache__"

magnet_names = list_subfolders_magnets + list_subfolders_circuits
programs = ['LEDET', 'SIGMA', 'FiQuS', 'ProteCCT', 'PSPICE']

x = widgets.interact_manual(STEAM_Library, case_model=cases, model_name=magnet_names, software=programs, flagBuild=True, verbose=True, flag_plot_all=False)
x.widget.children[0].description = 'Case'
x.widget.children[1].description = 'Magnet'
x.widget.children[2].description = 'Software'
x.widget.children[6].description = 'Build model'
# Out:
# interactive(children=(Dropdown(description='case_model', options=('magnet', 'circuit'), value='magnet'), Dropd…
