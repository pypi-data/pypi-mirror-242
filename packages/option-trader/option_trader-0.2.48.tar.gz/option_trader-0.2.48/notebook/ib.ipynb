# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import *
from ibapi.wrapper import *

class TestApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self)

    def nextValidId(self, orderId: int):
        
        mycontract = Contract()
        mycontract.symbol = "AAPL"
        mycontract.secType = "STK"
        mycontract.exchange = "SMART"
        mycontract.currency = "USD"

        self.reqMarketDataType(3)
        
        self.reqSecDefOptParams(0,"AAPL", "STK", "", 265598)        
#        self.reqHistoricalData(orderId, mycontract, "20230505 09:30:00 US/Eastern", "1 D", "1 hour", "TRADES", 0, 1, 0, [])

    def historicalData(self, reqId, bar):
        print(f"Historical Data: {bar}")

    def historicalDataEnd(self, reqId, start, end):
        print(f"End of HistoricalData")
        print(f"Start: {start}, End: {end}")


app = TestApp()
app.connect("127.0.0.1", 7496, 0)
app.run()
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usopt
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefnj
# ERROR 0 321 Error validating request.-'cB' : cause - Invalid security type -

# %%
import pandas as pd
import yfinance as yf
period = '50y'
interval = '1d'
symbol = 'USDCNY=X'

int_index = ['^DJI','^GSPC','^IXIC','^SOX','^N225','^HSI','^GDAXI','^FTSE','^FCHI','^STI', '^RUT', '^KS11']
currency = ['USDJPY=X', 'USDJPY=X', 'USDEUR=X', 'USDHKD=X', 'USDCAD=X', 'USDAUD=X', 'USDGBP=X' ]
bond_list = ['^TNX', '^TYX']
commodity_list = ['CL=F','HO=F','NG=F','GC=F','PL=F','SI=F','HG=F','PA=F','ZC=F','ZS=F','ZL=F','HE=F','LE=F','CC=F','KC=F','CT=F','OJ=F','SB=F']

total_list = int_index + currency + bond_list + commodity_list


new_list = ['SPX', 'TSLA', 'MSFT' ]

symbol='AAPL'
q = yf.Ticker(symbol)
hist = q.history(period=period, interval=interval)
hist
#hist.to_csv('c:\\data\\'+symbol+'.csv', sep=',')
    
#for symbol in new_list:
#    q = yf.Ticker(symbol)
#    hist = q.history(period=period, interval=interval)
#    hist.to_csv('c:\\data\\'+symbol+'.csv', sep=',')

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        self.reqMarketDataType(3)
        
    def tickPrice(self, reqId, tickType, price, attrib):
        #if tickType == 2 and reqId == 1:       
        print('The current ask price is: ', price)

def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

#Create contract object
apple_contract = Contract()
apple_contract.symbol = 'MSFT'
apple_contract.secType = 'STK'
apple_contract.exchange = 'SMART'
apple_contract.currency = 'USD'

#Request Market Data
app.reqMarketDataType(3)
app.reqMktData(1, apple_contract, '', False, False, [])

time.sleep(10) #Sleep interval to allow time for incoming price data
app.disconnect()

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
#from ibapi.contract import Contract
from ibapi.common import SetOfString
from ibapi.common import SetOfFloat

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        
        
    def securityDefinitionOptionParameter(self, 
                                          reqId:int, 
                                          exchange:str, 
                                          underlyingConId:int, 
                                          tradingClass:str, 
                                          multiplier:str, 
                                          expirations:SetOfString, 
                                          strikes:SetOfFloat):
        print("SecurityDefinitionOptionParameter.", "ReqId:", 
              reqId, "Exchange:", 
              exchange, "Underlying conId:", 
              underlyingConId, "TradingClass:", 
              tradingClass, "Multiplier:", 
              multiplier, "Expirations:", 
              expirations, "Strikes:", 
              str(strikes),"\n")

    def securityDefinitionOptionParameterEnd(self, reqId:int):

        print("SecurityDefinitionOptionParameterEnd. ReqId:", reqId)

def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7496, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

app.reqSecDefOptParams(0,"MSFT", "", "STK", 272093)

time.sleep(10) #Sleep interval to allow time for incoming price data
app.disconnect()
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usopt
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefnj
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: AMEX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: BOX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: CBOE2 Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: BATS Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: EMERALD Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: PHLX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: NASDAQOM Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: PSE Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: NASDAQBX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: SMART Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: GEMINI Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: ISE Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: MIAX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: PEARL Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: IBUSOPT Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: EDGX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: CBOE Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: MERCURY Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20231229', '20250117', '20240119', '20240315', '20240216', '20240719', '20231201', '20250620', '20260116', '20231208', '20231124', '20231222', '20240517', '20240419', '20231215', '20240920', '20251219', '20241220', '20240621'} Strikes: {515.0, 520.0, 525.0, 530.0, 535.0, 540.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0, 505.0, 510.0}
#
# SecurityDefinitionOptionParameterEnd. ReqId: 0

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract, ContractDetails
from ibapi.common import SetOfString
from ibapi.common import SetOfFloat

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        
        
    def contractDetails(self, reqId: int, contractDetails: ContractDetails):
        super().contractDetails(reqId, contractDetails)
        print(contractDetails)
        #printinstance(contractDetails)

    def contractDetailsEnd(self, reqId: int):
        super().contractDetailsEnd(reqId)
        print("ContractDetailsEnd. ReqId:", reqId)

def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7496, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

contract = Contract()
contract.symbol = 'AAPL'
contract.secType = "OPT"
contract.exchange = "SMART"
contract.currency = "USD"
      
x = app.reqContractDetails(0, contract)
time.sleep(10) #Sleep interval to allow time for incoming price data
#print(x)
app.disconnect()
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usopt
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefnj
# 513932168,AAPL,OPT,20240119,110,C,100,SMART,,USD,AAPL  240119C00110000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932260,AAPL,OPT,20240119,115,C,100,SMART,,USD,AAPL  240119C00115000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932316,AAPL,OPT,20240119,120,C,100,SMART,,USD,AAPL  240119C00120000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932385,AAPL,OPT,20240119,125,C,100,SMART,,USD,AAPL  240119C00125000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932450,AAPL,OPT,20240119,130,C,100,SMART,,USD,AAPL  240119C00130000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932521,AAPL,OPT,20240119,135,C,100,SMART,,USD,AAPL  240119C00135000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932568,AAPL,OPT,20240119,140,C,100,SMART,,USD,AAPL  240119C00140000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932630,AAPL,OPT,20240119,145,C,100,SMART,,USD,AAPL  240119C00145000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932676,AAPL,OPT,20240119,150,C,100,SMART,,USD,AAPL  240119C00150000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932766,AAPL,OPT,20240119,155,C,100,SMART,,USD,AAPL  240119C00155000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932830,AAPL,OPT,20240119,160,C,100,SMART,,USD,AAPL  240119C00160000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932890,AAPL,OPT,20240119,165,C,100,SMART,,USD,AAPL  240119C00165000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513932947,AAPL,OPT,20240119,170,C,100,SMART,,USD,AAPL  240119C00170000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513933001,AAPL,OPT,20240119,175,C,100,SMART,,USD,AAPL  240119C00175000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513933060,AAPL,OPT,20240119,180,C,100,SMART,,USD,AAPL  240119C00180000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513933125,AAPL,OPT,20240119,185,C,100,SMART,,USD,AAPL  240119C00185000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513933154,AAPL,OPT,20240119,190,C,100,SMART,,USD,AAPL  240119C00190000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1
# 513933196,AAPL,OPT,20240119,195,C,100,SMART,,USD,AAPL  240119C00195000,AAPL,False,,,,combo:,AAPL,0.01,ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,OPENCLOSE,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,PRICECHK,REL,RELPCTOFS,RELSTK,SCALE,SCALERST,SIZECHK,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF,SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL,EMERALD,IBUSOPT,1,265598,APPLE INC,202401,,,,US/Eastern,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,20231119:CLOSED;20231120:0930-20231120:1600;20231121:0930-20231121:1600;20231122:0930-20231122:1600;20231123:0930-20231123:1600;20231124:0930-20231124:1600,,0,AAPL,STK,32,109,109,109,109,109,109,109,32,109,32,109,109,109,109,109,109,32,2,None,20240119,,,,,,,False,False,0,False,,,,,False,,1,1,1

# %%
from ibapi.ticktype import TickTypeEnum

for i in range(91):
	print(TickTypeEnum.to_str(i), i)
# Out:
# BID_SIZE 0
# BID 1
# ASK 2
# ASK_SIZE 3
# LAST 4
# LAST_SIZE 5
# HIGH 6
# LOW 7
# VOLUME 8
# CLOSE 9
# BID_OPTION_COMPUTATION 10
# ASK_OPTION_COMPUTATION 11
# LAST_OPTION_COMPUTATION 12
# MODEL_OPTION 13
# OPEN 14
# LOW_13_WEEK 15
# HIGH_13_WEEK 16
# LOW_26_WEEK 17
# HIGH_26_WEEK 18
# LOW_52_WEEK 19
# HIGH_52_WEEK 20
# AVG_VOLUME 21
# OPEN_INTEREST 22
# OPTION_HISTORICAL_VOL 23
# OPTION_IMPLIED_VOL 24
# OPTION_BID_EXCH 25
# OPTION_ASK_EXCH 26
# OPTION_CALL_OPEN_INTEREST 27
# OPTION_PUT_OPEN_INTEREST 28
# OPTION_CALL_VOLUME 29
# OPTION_PUT_VOLUME 30
# INDEX_FUTURE_PREMIUM 31
# BID_EXCH 32
# ASK_EXCH 33
# AUCTION_VOLUME 34
# AUCTION_PRICE 35
# AUCTION_IMBALANCE 36
# MARK_PRICE 37
# BID_EFP_COMPUTATION 38
# ASK_EFP_COMPUTATION 39
# LAST_EFP_COMPUTATION 40
# OPEN_EFP_COMPUTATION 41
# HIGH_EFP_COMPUTATION 42
# LOW_EFP_COMPUTATION 43
# CLOSE_EFP_COMPUTATION 44
# LAST_TIMESTAMP 45
# SHORTABLE 46
# FUNDAMENTAL_RATIOS 47
# RT_VOLUME 48
# HALTED 49
# BID_YIELD 50
# ASK_YIELD 51
# LAST_YIELD 52
# CUST_OPTION_COMPUTATION 53
# TRADE_COUNT 54
# TRADE_RATE 55
# VOLUME_RATE 56
# LAST_RTH_TRADE 57
# RT_HISTORICAL_VOL 58
# IB_DIVIDENDS 59
# BOND_FACTOR_MULTIPLIER 60
# REGULATORY_IMBALANCE 61
# NEWS_TICK 62
# SHORT_TERM_VOLUME_3_MIN 63
# SHORT_TERM_VOLUME_5_MIN 64
# SHORT_TERM_VOLUME_10_MIN 65
# DELAYED_BID 66
# DELAYED_ASK 67
# DELAYED_LAST 68
# DELAYED_BID_SIZE 69
# DELAYED_ASK_SIZE 70
# DELAYED_LAST_SIZE 71
# DELAYED_HIGH 72
# DELAYED_LOW 73
# DELAYED_VOLUME 74
# DELAYED_CLOSE 75
# DELAYED_OPEN 76
# RT_TRD_VOLUME 77
# CREDITMAN_MARK_PRICE 78
# CREDITMAN_SLOW_MARK_PRICE 79
# DELAYED_BID_OPTION 80
# DELAYED_ASK_OPTION 81
# DELAYED_LAST_OPTION 82
# DELAYED_MODEL_OPTION 83
# LAST_EXCH 84
# LAST_REG_TIME 85
# FUTURES_OPEN_INTEREST 86
# AVG_OPT_VOLUME 87
# DELAYED_LAST_TIMESTAMP 88
# SHORTABLE_SHARES 89
# DELAYED_HALTED 90

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract
from threading import Timer

class TestApp(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)

    #def error(self, reqId, errorCode, errorString):
    #    print("Error: ", reqId, " ", errorCode, " ", errorString)

    def nextValidId(self, orderId):
        self.start()

    def updatePortfolio(self, contract: Contract, position: float, marketPrice: float, marketValue: float,
                        averageCost: float, unrealizedPNL: float, realizedPNL: float, accountName: str):
        print("UpdatePortfolio.", "Symbol:", contract.symbol, "SecType:", contract.secType, "Exchange:", contract.exchange,
              "Position:", position, "MarketPrice:", marketPrice, "MarketValue:", marketValue, "AverageCost:", averageCost,
              "UnrealizedPNL:", unrealizedPNL, "RealizedPNL:", realizedPNL, "AccountName:", accountName)

    def updateAccountValue(self, key: str, val: str, currency: str, accountName: str):
        print("UpdateAccountValue. Key:", key, "Value:", val, "Currency:", currency, "AccountName:", accountName)

    def updateAccountTime(self, timeStamp: str):
        print("UpdateAccountTime. Time:", timeStamp)

    def accountDownloadEnd(self, accountName: str):
        print("AccountDownloadEnd. Account:", accountName)

    def start(self):
        # Account number can be omitted when using reqAccountUpdates with single account structure
        self.reqAccountUpdates(True, "")

    def stop(self):
        self.reqAccountUpdates(False, "")
        self.done = True
        self.disconnect()

def main():
    app = TestApp()
    app.connect("127.0.0.1", 7496, 0)

    Timer(5, app.stop).start()
    app.run()

if __name__ == "__main__":
    main()
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usopt
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefnj
# ERROR 2147483647 321 Error validating request.-'bv' : cause - The account code is required for this operation.

# %%
class TestApp(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)

    def error(self, reqId, errorCode, errorString):
        print("Error: ", reqId, " ", errorCode, " ", errorString)

    def nextValidId(self, orderId):
        self.start()

    def updatePortfolio(self, contract: Contract, position: float, marketPrice: float, marketValue: float,
                        averageCost: float, unrealizedPNL: float, realizedPNL: float, accountName: str):
        print("UpdatePortfolio.", "Symbol:", contract.symbol, "SecType:", contract.secType, "Exchange:", contract.exchange,
              "Position:", position, "MarketPrice:", marketPrice, "MarketValue:", marketValue, "AverageCost:", averageCost,
              "UnrealizedPNL:", unrealizedPNL, "RealizedPNL:", realizedPNL, "AccountName:", accountName)

    def updateAccountValue(self, key: str, val: str, currency: str, accountName: str):
        print("UpdateAccountValue. Key:", key, "Value:", val, "Currency:", currency, "AccountName:", accountName)

    def updateAccountTime(self, timeStamp: str):
        print("UpdateAccountTime. Time:", timeStamp)

    def accountDownloadEnd(self, accountName: str):
        print("AccountDownloadEnd. Account:", accountName)

    def start(self):
        # Account number can be omitted when using reqAccountUpdates with single account structure
        self.reqAccountUpdates(True, "")

    def stop(self):
        self.reqAccountUpdates(False, "")
        self.done = True
        self.disconnect()

# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract

import threading
import time

class IBapi(EWrapper, EClient):
	def __init__(self):
		EClient.__init__(self, self)
	def historicalData(self, reqId, bar):
		print(f'Time: {bar.date} Close: {bar.close}')
		
def run_loop():
	app.run()

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

#Create contract object
eurusd_contract = Contract()
eurusd_contract.symbol = 'EUR'
eurusd_contract.secType = 'CASH'
eurusd_contract.exchange = 'IDEALPRO'
eurusd_contract.currency = 'USD'

#Request historical candles
app.reqHistoricalData(1, eurusd_contract, '', '2 D', '1 hour', 'BID', 0, 2, False, [])

time.sleep(5) #sleep to allow enough time for data to be returned
app.disconnect()

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract
from ibapi.order import *

import threading
import time

class IBapi(EWrapper, EClient):
	def __init__(self):
		EClient.__init__(self, self)

	def nextValidId(self, orderId: int):
		super().nextValidId(orderId)
		self.nextorderId = orderId
		print('The next valid order id is: ', self.nextorderId)

	def orderStatus(self, orderId, status, filled, remaining, avgFullPrice, permId, parentId, lastFillPrice, clientId, whyHeld, mktCapPrice):
		print('orderStatus - orderid:', orderId, 'status:', status, 'filled', filled, 'remaining', remaining, 'lastFillPrice', lastFillPrice)
	
	def openOrder(self, orderId, contract, order, orderState):
		print('openOrder id:', orderId, contract.symbol, contract.secType, '@', contract.exchange, ':', order.action, order.orderType, order.totalQuantity, orderState.status)

	def execDetails(self, reqId, contract, execution):
		print('Order Executed: ', reqId, contract.symbol, contract.secType, contract.currency, execution.execId, execution.orderId, execution.shares, execution.lastLiquidity)


def run_loop():
	app.run()

#Function to create FX Order contract
def FX_order(symbol):
	contract = Contract()
	contract.symbol = symbol[:3]
	contract.secType = 'CASH'
	contract.exchange = 'IDEALPRO'
	contract.currency = symbol[3:]
	return contract

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

app.nextorderId = None

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

#Check if the API is connected via orderid
while True:
	if isinstance(app.nextorderId, int):
		print('connected')
		break
	else:
		print('waiting for connection')
		time.sleep(1)

#Create order object
order = Order()
order.action = 'BUY'
order.totalQuantity = 100000
order.orderType = 'LMT'
order.lmtPrice = '1.10'

#Place order
app.placeOrder(app.nextorderId, FX_order('EURUSD'), order)
#app.nextorderId += 1

time.sleep(3)

#Cancel order 
print('cancelling order')
app.cancelOrder(app.nextorderId, "")

time.sleep(3)
app.disconnect()

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect('127.0.0.1', 7496, clientId=4)

contract = Forex('EURUSD')

x = ib.reqSecDefOptParams("AAPL", "", "STK", 265598)

print(x[0])

ib.disconnect()

# convert to pandas dataframe:
#df = util.df(bars)
#print(df)
# Out:
# Peer closed connection. clientId 4 already in use?
# API connection failed: TimeoutError()
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\tasks.py:490, in wait_for(fut, timeout)
#     489 try:
# --> 490     return fut.result()
#     491 except exceptions.CancelledError as exc:
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\futures.py:198, in Future.result(self)
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\tasks.py:269, in Task.__step(***failed resolving arguments***)
#     268     else:
# --> 269         result = coro.throw(exc)
#     270 except StopIteration as exc:
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\tasks.py:684, in _wrap_awaitable(awaitable)
#     679 """Helper for asyncio.ensure_future().
#     680
#     681 Wraps awaitable (an object with __await__) into a coroutine
#     682 that will later be wrapped in a Task by ensure_future().
#     683 """
# --> 684 return (yield from awaitable.__await__())
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\tasks.py:339, in Task.__wakeup(self, future)
#     338 try:
# --> 339     future.result()
#     340 except BaseException as exc:
#     341     # This may also be a cancellation.
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\futures.py:198, in Future.result(self)
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# Cell In[6], line 7
#       3 util.startLoop()  # uncomment this line when in a notebook
#       5 ib = IB()
# ----> 7 ib.connect('127.0.0.1', 7496, clientId=4)
#       9 contract = Forex('EURUSD')
#      11 x = ib.reqSecDefOptParams("AAPL", "", "STK", 265598)
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\ib_insync\ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
#     259         timeout: float = 4, readonly: bool = False, account: str = ''):
#     260     """
#     261     Connect to a running TWS or IB gateway application.
#     262     After the connection is made the client is fully synchronized
#    (...)
#     277         account: Main account to receive updates for.
#     278     """
# --> 279     return self._run(self.connectAsync(
#     280         host, port, clientId, timeout, readonly, account))
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\ib_insync\ib.py:318, in IB._run(self, *awaitables)
#     317 def _run(self, *awaitables: Awaitable):
# --> 318     return util.run(*awaitables, timeout=self.RequestTimeout)
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\ib_insync\util.py:341, in run(timeout, *awaitables)
#     339 globalErrorEvent.connect(onError)
#     340 try:
# --> 341     result = loop.run_until_complete(task)
#     342 except asyncio.CancelledError as e:
#     343     raise globalErrorEvent.value() or e
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\nest_asyncio.py:90, in _patch_loop.<locals>.run_until_complete(self, future)
#      87 if not f.done():
#      88     raise RuntimeError(
#      89         'Event loop stopped before Future completed.')
# ---> 90 return f.result()
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\tasks.py:267, in Task.__step(***failed resolving arguments***)
#     263 try:
#     264     if exc is None:
#     265         # We use the `send` method directly, because coroutines
#     266         # don't have `__iter__` and `__next__` methods.
# --> 267         result = coro.send(None)
#     268     else:
#     269         result = coro.throw(exc)
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\ib_insync\ib.py:1748, in IB.connectAsync(self, host, port, clientId, timeout, readonly, account)
#    1745 timeout = timeout or None
#    1746 try:
#    1747     # establish API connection
# -> 1748     await self.client.connectAsync(host, port, clientId, timeout)
#    1750     # autobind manual orders
#    1751     if clientId == 0:
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\ib_insync\client.py:217, in Client.connectAsync(self, host, port, clientId, timeout)
#     213     msg = b'API\0' + self._prefix(b'v%d..%d%s' % (
#     214         self.MinClientVersion, self.MaxClientVersion,
#     215         b' ' + self.connectOptions if self.connectOptions else b''))
#     216     self.conn.sendMsg(msg)
# --> 217     await asyncio.wait_for(self.apiStart, timeout)
#     218     self._logger.info('API connection ready')
#     219 except BaseException as e:
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\asyncio\tasks.py:492, in wait_for(fut, timeout)
#     490             return fut.result()
#     491         except exceptions.CancelledError as exc:
# --> 492             raise exceptions.TimeoutError() from exc
#     493 finally:
#     494     timeout_handle.cancel()
#
# TimeoutError:

# %%
x[0].expirations
# Out:
# ['20231124',
#  '20231201',
#  '20231208',
#  '20231215',
#  '20231222',
#  '20231229',
#  '20240119',
#  '20240216',
#  '20240315',
#  '20240419',
#  '20240621',
#  '20240719',
#  '20240920',
#  '20241220',
#  '20250117',
#  '20250620',
#  '20250919',
#  '20251219',
#  '20260116']

# %%
from ib_insync import *

try:
    get_ipython    
    util.startLoop()  # uncomment this line when in a notebook
except:
    pass
    
ib = IB()

ib.connect('127.0.0.1', 7497, clientId=3)

# %%
from ib_insync import *
import numpy as np
import pandas as pd
from datetime import time, date, datetime, timedelta
from pytz import timezone

option_chain_rec = {'exp_date':[''],'strike':[np.nan],
                'lastPirce':[np.nan],'bid':[np.nan], 'ask':[np.nan],
                'bidSize':[np.nan], 'askSize':[np.nan], 'volume':[np.nan],
                'open':[np.nan], 'high':[np.nan], 'low':[np.nan], 'close':[np.nan],
                'impliedVolatility':[np.nan], 'delta':[np.nan], 'gamma':[np.nan],
                'vega':[np.nan], 'theta':[np.nan],'sigma':[np.nan]}

def get_option_chain(symbol, stock_price, strike_limit_pert =0.05, max_days_to_expire=30):
    
    trade_date = datetime.now(timezone('US/Eastern'))    
    
    util.startLoop()  # uncomment this line when in a notebook

    ib = IB()

    ib.connect('127.0.0.1', 7496, clientId=4)

    x = ib.reqMatchingSymbols(symbol)

    conId = x[0].contract.conId

    x = ib.reqSecDefOptParams(symbol, "", "STK", conId)

    exp_date_list = list(filter(lambda x: (pd.Timestamp(x).tz_localize(timezone('US/Eastern'))-trade_date).days < max_days_to_expire, x[0].expirations))   
   
    strikes = list(filter(lambda x: x >= stock_price * (1-strike_limit_pert) and x <= stock_price * (1+strike_limit_pert), x[0].strikes))   
    
    #df_new_row = pd.DataFrame.from_records(self.empty_rec)

    ib.reqMarketDataType(3)
        
    df = pd.DataFrame()
    for exp_date in exp_date_list:
        for strike in strikes:        
            print(exp_date, strike)
            contract = Contract()
            contract.symbol = symbol
            contract.secType = 'OPT'
            contract.exchange = 'SMART'
            contract.currency = 'USD'
            contract.lastTradeDateOrContractMonth = exp_date
            contract.strike = strike
            contract.right = 'C'
            contract.multiplier = '100'
            ib.qualifyContracts(contract) 
            x = ib.reqMktData(contract, '', False, False, [])
            ib.sleep(5)            
            ne = pd.DataFrame.from_records(option_chain_rec)
            ne.exp_date = exp_date
            ne.strike = strike    
            ne.bid =  x.bid
            ne.bidSize = x.bidSize
            ne.ask = x.ask
            ne.askSize = x.askSize
            ne.lastPrice = x.last
            ne.open = x.open
            ne.high = x.high
            ne.low = x.low
            ne.close = x.close
            
            if x.bidGreeks != None:
                print(x.bidGreeks)
                ne.impliedVolatility = (x.bidGreeks.impliedVol + x.askGreeks.impliedVol) / 2
                ne.delta = (x.bidGreeks.delta + x.askGreeks.delta) / 2
                ne.gamma = (x.bidGreeks.gamma + x.askGreeks.gamma) / 2
                ne.vega =  (x.bidGreeks.vega + x.askGreeks.vega) / 2
                ne.theta = (x.bidGreeks.theta  + x.askGreeks.theta ) / 2
                ne.sigma = (x.bidGreeks.sigma  + x.askGreeks.sigma ) / 2
                ne.volume = x.volume

            df = pd.concat([df, ne])  
                        
    ib.disconnect()
    
    return df

df = get_option_chain('MSFT', 320)

df
# Out:
# 20231124 305.0
# 20231124 307.5
# Error 200, reqId 9: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231124', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231124', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 10: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231124', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231124 310.0
# 20231124 312.5
# 20231124 315.0
# 20231124 317.5
# 20231124 320.0
# 20231124 322.5
# 20231124 325.0
# 20231124 327.5
# 20231124 330.0
# 20231124 332.5
# 20231124 335.0
# 20231201 305.0
# 20231201 307.5
# Error 200, reqId 35: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 36: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231201 310.0
# 20231201 312.5
# Error 200, reqId 39: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 40: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231201 315.0
# 20231201 317.5
# Error 200, reqId 43: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 44: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231201 320.0
# 20231201 322.5
# Error 200, reqId 47: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 48: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231201 325.0
# 20231201 327.5
# Error 200, reqId 51: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 52: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231201 330.0
# 20231201 332.5
# Error 200, reqId 55: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 56: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231201', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231201 335.0
# 20231208 305.0
# 20231208 307.5
# Error 200, reqId 61: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 62: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231208 310.0
# 20231208 312.5
# Error 200, reqId 65: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 66: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231208 315.0
# 20231208 317.5
# Error 200, reqId 69: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 70: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231208 320.0
# 20231208 322.5
# Error 200, reqId 73: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 74: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231208 325.0
# 20231208 327.5
# Error 200, reqId 77: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 78: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231208 330.0
# 20231208 332.5
# Error 200, reqId 81: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 82: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231208', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231208 335.0
# 20231215 305.0
# 20231215 307.5
# Error 200, reqId 87: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 88: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231215 310.0
# 20231215 312.5
# Error 200, reqId 91: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 92: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231215 315.0
# 20231215 317.5
# Error 200, reqId 95: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 96: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231215 320.0
# 20231215 322.5
# Error 200, reqId 99: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 100: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231215 325.0
# 20231215 327.5
# Error 200, reqId 103: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 104: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231215 330.0
# 20231215 332.5
# Error 200, reqId 107: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 108: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20231215', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20231215 335.0
#    ask  askSize  bid  bidSize  close  delta  exp_date  gamma   high  \
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0  NaN      NaN  NaN      NaN  66.65    NaN  20231124    NaN  60.69
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0  NaN      NaN  NaN      NaN  56.68    NaN  20231124    NaN  52.90
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0  NaN      NaN  NaN      NaN  51.69    NaN  20231124    NaN  46.23
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0  NaN      NaN  NaN      NaN  46.71    NaN  20231124    NaN  43.08
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231124    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  41.74    NaN  20231124    NaN  37.24
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN  67.10    NaN  20231201    NaN  63.05
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN  47.23    NaN  20231201    NaN  43.12
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231201    NaN    NaN
# 0  NaN      NaN  NaN      NaN  42.28    NaN  20231201    NaN  38.33
# 0 -1.0      0.0 -1.0      0.0  72.06    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  47.34    NaN  20231208    NaN  42.19
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231208    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  42.42    NaN  20231208    NaN  39.08
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0  NaN      NaN  NaN      NaN  62.98    NaN  20231215    NaN  57.50
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0  NaN      NaN  NaN      NaN  58.03    NaN  20231215    NaN  54.53
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0  NaN      NaN  NaN      NaN  53.15    NaN  20231215    NaN  49.19
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  48.28    NaN  20231215    NaN  45.80
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20231215    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  43.45    NaN  20231215    NaN  39.65
#
#    impliedVolatility  lastPirce    low  open  sigma  strike  theta  vega  \
# 0                NaN        NaN    NaN   NaN    NaN   305.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN  60.69   NaN    NaN   310.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   312.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   315.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN  52.83   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN  43.73   NaN    NaN   325.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   327.5    NaN   NaN
# 0                NaN        NaN  40.50   NaN    NaN   330.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   332.5    NaN   NaN
# 0                NaN        NaN  34.50   0.0    NaN   335.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   305.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN  63.05   NaN    NaN   310.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   312.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   315.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   325.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   327.5    NaN   NaN
# 0                NaN        NaN  42.12   NaN    NaN   330.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   332.5    NaN   NaN
# 0                NaN        NaN  35.00   NaN    NaN   335.0    NaN   NaN
# 0                NaN        NaN    NaN   0.0    NaN   305.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   310.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   312.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   315.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   325.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   327.5    NaN   NaN
# 0                NaN        NaN  42.19   0.0    NaN   330.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   332.5    NaN   NaN
# 0                NaN        NaN  39.08   0.0    NaN   335.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   305.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   310.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   312.5    NaN   NaN
# 0                NaN        NaN  54.83   NaN    NaN   315.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN  51.45   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN  45.55   0.0    NaN   325.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   327.5    NaN   NaN
# 0                NaN        NaN  40.00   0.0    NaN   330.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   332.5    NaN   NaN
# 0                NaN        NaN  35.35   0.0    NaN   335.0    NaN   NaN
#
#    volume
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN

# %%
option_chain_rec = {'exp_date':[''],'strike':[np.nan],
                'lastPirce':[np.nan],'bid':[np.nan], 'ask':[np.nan],
                'bidSize':[np.nan], 'askSize':[np.nan], 'volume':[np.nan],
                'open':[np.nan], 'high':[np.nan], 'low':[np.nan], 'close':[np.nan],
                'impliedVolatility':[np.nan], 'delta':[np.nan], 'gamma':[np.nan],
                'vega':[np.nan], 'theta':[np.nan],'sigma':[np.nan]}
    
df = pd.DataFrame()

for exp_date in exp_date_list:
    for strike in strikes:        
        ne = pd.DataFrame.from_records(option_chain_rec)
        ne.exp_date = exp_date
        ne.strike = strike
        df = pd.concat([df, ne])
        
df

# %%
import pandas as pd
import pandas_ta as ta
import pymannkendall as mk
import math
import numpy as np
from datetime import time, date, datetime, timedelta
from pytz import timezone

max_days_to_expire = 30

exp_date_list = []

exp_tbl = x.expirations        
trade_date = datetime.now(timezone('US/Eastern'))


exp_date_list = list(filter(lambda x: (pd.Timestamp(x).tz_localize(timezone('US/Eastern'))-trade_date).days < 30, x.expirations))   
    
#for exp_date in exp_tbl:    
#    exp_date = pd.Timestamp(exp_date)
#    days_to_expire = (exp_date.tz_localize(timezone('US/Eastern'))-trade_date).days

#    if days_to_expire <= 0:
#        continue

#    if days_to_expire > max_days_to_expire:
#        break

#    exp_date_list.append(exp_date)

print(exp_date_list)

# %%
class IBConfig:
    port = 7497
    clientId = 8888
    marketDataType = 3 #https://interactivebrokers.github.io/tws-api/market_data_type.html

# %%
from ib_insync import *

class IBClient:    

    connection = None     
    
    @staticmethod
    def get_client():
        util.startLoop()  # uncomment this line when in a notebook        
        if IBClient.connection == None:
            ib = IB()
            ib.connect('127.0.0.1', IBConfig.port, clientId=IBConfig.clientId)            
            IBClient.connection = ib
            # delayed quote
            ib.reqMarketDataType(IBConfig.marketDataType)            
            return ib
        else:
            return IBClient.connection
        
    @staticmethod
    def disconnect():
        if IBClient.connection != None:
            IBClient.connection.client.disconnect()
            IBClient.connection = None

# %%
mycontract = Contract()
mycontract.symbol = "AAPL"
mycontract.secType = "STK"
mycontract.exchange = "SMART"
mycontract.currency = "USD"
        
contract = Forex('EURUSD')

ib.reqMarketDataType(3)
    
#https://interactivebrokers.github.io/tws-api/historical_bars.html#hd_what_to_show

bars = ib.reqHistoricalData(
    mycontract, endDateTime='', durationStr='1 y',
    barSizeSetting='1 day', whatToShow='TRADES', useRTH=True)

# convert to pandas dataframe:
df = util.df(bars)

df.rename(columns = {'date':'Date', 'open':'Open', 'high':'High', 'low':'Low',
                     'close':'Close', 'volume':'Volume', 'average':'Average'}, inplace = True)

print(df.set_index('Date'))

ib.disconnect()

# %%
from ib_insync import *

try:
    get_ipython    
    util.startLoop()  # uncomment this line when in a notebook
except:
    pass
    
ib = IB()

symbol = 'MSFT'

ib.connect('127.0.0.1', 7497, clientId=0)

contract = Contract()
contract.symbol =  symbol
contract.secType = "OPT"
contract.exchange = "SMART"
contract.currency = "USD"

ib.reqMarketDataType(3)
    
#https://interactivebrokers.github.io/tws-api/historical_bars.html#hd_what_to_show

x = ib.reqMatchingSymbols(symbol)


conId = x[0].contract.conId

x = ib.reqSecDefOptParams(symbol, "", "STK", conId)

print(x[0])


ib.disconnect()

# %%
x[0].contract.conId

# %%
from ib_insync import *

try:
    get_ipython    
    util.startLoop()  # uncomment this line when in a notebook
except:
    pass
    
ib = IB()

ib.connect('127.0.0.1', 7497, clientId=3)

mycontract = Contract()
mycontract.symbol = "AAPL"
mycontract.secType = "OPT"
mycontract.exchange = "SMART"
mycontract.currency = "USD"
        
contract = Forex('EURUSD')

ib.reqMarketDataType(3)
    
#https://interactivebrokers.github.io/tws-api/historical_bars.html#hd_what_to_show

x = ib.reqSecDefOptParams("MSFT", "", "STK", 272093)

print(x[0])

ib.disconnect()

# %%
#Legal interval are: 1 secs, 5 secs, 10 secs, 15 secs, 30 secs, 1 min, 
#    2 mins, 3 mins, 5 mins, 10 mins, 15 mins, 20 mins, 30 mins, 
#    1 hour, 2 hours, 3 hours, 4 hours, 8 hours, 1 day, 1W, 1M, 
                
def get_price_history(symbol, period="1 Y", interval="1 day", start=None, end=None):    

    ib = IBClient.get_client()
    
    contract = Contract()
    contract.symbol = symbol
    contract.secType = "STK"
    contract.exchange = "SMART"
    contract.currency = "USD"

    bars = ib.reqHistoricalData(
        contract, endDateTime='', durationStr=period,
        barSizeSetting=interval, whatToShow='TRADES', useRTH=True)

    df =  util.df(bars)
    df.rename(columns = {'date':'Date', 'open':'Open', 'high':'High', 'low':'Low',
                         'close':'Close', 'volume':'Volume', 'average':'Average'}, inplace = True)
    
    IBClient.disconnect()
    
    return df.set_index('Date')

get_price_history('AAPL')

# %%
apple_contract = Contract()
apple_contract.symbol = 'MSFT'
apple_contract.secType = 'STK'
apple_contract.exchange = 'SMART'
apple_contract.currency = 'USD'


#Request Market Data
app.reqMarketDataType(3)
app.reqMktData(1, apple_contract, '', False, False, [])

contract.lastTradeDateOrContractMonth = '20230519'
contract.strike = 305.0
contract.right = 'C'
contract.multiplier = '100'

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect('127.0.0.1', 7497, clientId=4)

contract = Contract()
contract.symbol = 'MSFT'
contract.secType = 'OPT'
contract.exchange = 'SMART'
contract.currency = 'USD'
contract.lastTradeDateOrContractMonth = '20230519'
contract.strike = 307.5
contract.right = 'C'
contract.multiplier = '100'
ib.qualifyContracts(contract) 
ib.reqMarketDataType(3)
x = ib.reqMktData(contract, '', False, False, [])
ib.sleep(5)

print(vars(x))

ib.disconnect()

# convert to pandas dataframe:
#df = util.df(bars)
#print(df)

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

def get_ticker(symbol):
    
    ib = IB()
    ib.connect('127.0.0.1', 7497, clientId=4)

    contract = Contract()
    contract.symbol = symbol
    contract.secType = 'STK'
    contract.exchange = 'SMART'
    contract.currency = 'USD'

    ib.qualifyContracts(contract) 
    ib.reqMarketDataType(3)
    x = ib.reqMktData(contract, '', False, False, [])
    ib.sleep(5)

    #return x.bid, x.ask, x.last, x.bidGreeks.impliedVol, x.bidGreeks.delta, x.bidGreeks.gamma, x.bidGreeks.vega, x.bidGreeks.theta

    ib.disconnect()

    return x

x = get_ticker('AAPL')    

print(vars(x))

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

def get_option_price(symbol, exp_date, strike, otype):
    
    ib = IB()
    ib.connect('127.0.0.1', 7497, clientId=4)

    contract = Contract()
    contract.symbol = symbol
    contract.secType = 'OPT'
    contract.exchange = 'SMART'
    contract.currency = 'USD'
    contract.lastTradeDateOrContractMonth = exp_date #'20230512'
    contract.strike = strike
    contract.right = otype
    contract.multiplier = '100'
    ib.qualifyContracts(contract) 
    ib.reqMarketDataType(3)
    x = ib.reqMktData(contract, '', False, False, [])
    ib.sleep(5)
    
    return x.bid, x.ask, x.last, x.bidGreeks.impliedVol, x.bidGreeks.delta, x.bidGreeks.gamma, x.bidGreeks.vega, x.bidGreeks.theta

    ib.disconnect()

get_option_price('AAPL', '20230512', 172.5, 'C')

# %%
#https://algotrading101.com/learn/ib_insync-interactive-brokers-api-guide/

from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect()

# %%
nflx_contract = Stock('NFLX', 'SMART', 'USD')

# %%
ib.qualifyContracts(nflx_contract)

# %%
data = ib.reqMktData(nflx_contract)

# %%
data.marketPrice()

# %%
eur_usd_contract = Forex('EURUSD', 'IDEALPRO')
ib.qualifyContracts(eur_usd_contract)

# %%
btc_fut_contract = Future('BRR', '20231031', 'CMECRYPTO')
ib.qualifyContracts(btc_fut_contract)

# %%
btc_fut_cont_contract = ContFuture('BRR', 'CMECRYPTO')
ib.qualifyContracts(btc_fut_cont_contract)

# %%
ib.reqMarketDataType(3)

historical_data_nflx = ib.reqHistoricalData(
    nflx_contract, 
    '', 
    barSizeSetting='15 mins', 
    durationStr='2 D', 
    whatToShow='MIDPOINT', 
    useRTH=True
    )

# %%
type(historical_data_nflx)

# %%
historical_data_nflx[-1]

# %%
util.df(historical_data_nflx)

# %%
nflx_order = MarketOrder('BUY', 200)

# %%
trade = ib.placeOrder(nflx_contract, nflx_order)

# %%
def order_status(trade):
    print(trade.orderStatis.status)
    if trade.orderStatus.status == 'Filled':
        fill = trade.fills[-1]
        
        print(f'{fill.time} - {fill.execution.side} {fill.contract.symbol} {fill.execution.shares} @ {fill.execution.avgPrice}')

# %%
from ib_insync import *

def order_status(trade):
    print(trade.orderStatis.status)
    if trade.orderStatus.status == 'Filled':
        fill = trade.fills[-1]
        
        print(f'{fill.time} - {fill.execution.side} {fill.contract.symbol} {fill.execution.shares} @ {fill.execution.avgPrice}')
        
util.startLoop()  # uncomment this line when in a noteboo
nflx_order = MarketOrder('BUY', 100)
msft_order = MarketOrder('BUY', 100)

nflx_trade = ib.placeOrder(nflx_contract, nflx_order)

trade.filledEvent+= order_status

# %%
eurusd_bracket_order = ib.bracketOrder(
    'BUY',
    100000,
    limitPrice=1.19,
    takeProfitPrice=1.20,
    stopLossPrice=1.18
)

# %%
for ord in eurusd_bracket_order:
    ib.placeOrder(eur_usd_contract, ord)

# %%
visa_contract = Stock('V', 'SMART', 'USD')
ib.qualifyContracts(visa_contract)

# %%
price_condition = PriceCondition(
    price=200,
    conId=visa_contract.conId,
    exch=visa_contract.exchange
    )

# %%
ma_contract = Stock('MA', 'SMART', 'USD')
ib.qualifyContracts(ma_contract)

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect('127.0.0.1', 7497, clientId=123)

# %%
P1S_contract = Option('MSFT', '20230519', 290, 'C', 'SMART')
ib.qualifyContracts(P1S_contract) 
P1L_contract = Option('MSFT', '20230519', 300, 'C', 'SMART')
ib.qualifyContracts(P1L_contract) 

P1S_contract.ratio = 1
P1S_contract.action = 'SELL'
P1S_contract.openClose = 0
P1S_contract.shortSaleSlot = 0
P1S_contract.exemptCode=0
P1S_contract.designatedLocation = 0   

P1L_contract.ratio = 1
P1L_contract.action = 'BUY'
P1L_contract.openClose = 0
P1L_contract.shortSaleSlot = 0
P1L_contract.exemptCode=0
P1L_contract.designatedLocation = 0

# %%
comboLegs = [P1S_contract, P1L_contract]

# %%
contract = Contract(symbol='MSFT', secType='BAG', exchange='SMART', currency='USD', comboLegs=comboLegs)

# %%
order = Order(action='BUY', orderType='LMT', totalQuantity=5, lmtPrice=8)

# %%
trade = ib.placeOrder(contract, order)

def order_status(trade):
    print(trade.orderStatus.status)
    if trade.orderStatus.status == 'Filled':
        fill = trade.fills[-1]
        
        print(f'{fill.time} - {fill.execution.side} {fill.contract.symbol} {fill.execution.shares} @ {fill.execution.avgPrice}')
        

trade.filledEvent+= order_status

# %%
trade.orderStatus

# %%
trade.log

# %%
ib.cancelOrder(order)

# %%
trade

# %%
order.orderId

# %%
list = [1,2,3]

# %%
list.pop(1)

# %%
x = ib.portfolio(account='DU7131629')
p = util.df(x)
p

# %%
x = ib.accountValues(account='')
df = util.df(x)
for index, row in df.iterrows():
    print(row['tag'], '\t----\t', row['value'])

# %%
ib.managedAccounts()

# %%
x = ib.accountSummary()
df = util.df(x)

for index, row in df.iterrows():
    print(row['tag'], '\t----\t', row['value'])

# %%
util.df(ib.positions())

# %%
util.df(ib.orders())

# %%
util.df(ib.fills())

# %%
dir(ib)

# %%
import sys
import traceback
#sys.exc_info()
#traceback.format_exc(sys.exc_info()) 

etype, value, tb = sys.exc_info()

print(''.join(traceback.format_exception(etype, value, tb, limit)))

# %%
import traceback
import sys
from pprint import pprint

#from traceback_example import produce_exception

try:
    produce_exception()
except Exception as err:
    #tb = traceback.TracebackException.from_exception(err)

    #print('Handled at stack lvl 0')
    #print(''.join(tb.stack.format()))    
    
    exc_type, exc_value, exc_tb = sys.exc_info()
    print(exc_type)
    print(exc_value)
    #print(exc_tb)
    print(traceback.format_exception(exc_type, exc_value, exc_tb))
    #print(exc_tb.tb_frame)
    #print(exc_tb.tb_lasti)
    #print(exc_tb.tb_lineno)
    #print(exc_tb.tb_next)

# %%
import traceback

try:
    1/0
except Exception as ex:
    print(ex)
    print(traceback.format_exc())
    # or
    #print(sys.exc_info()[2])    
    #x = traceback.print_exception(type(ex), ex, ex.__traceback__)
    #print(ex.__traceback__)

# %%
from ib_insync import *

util.startLoop()  # only use in interactive environments (i.e. Jupyter Notebooks)

# %%
ib = IB()
#ib.connect()

ib.connect("127.0.0.1", 4002, clientId=21,account='DU7131629')

# %%
ib = IB()
util.logToConsole('DEBUG')
ib.connect(host='127.0.0.1', port=7497, clientId=1)
