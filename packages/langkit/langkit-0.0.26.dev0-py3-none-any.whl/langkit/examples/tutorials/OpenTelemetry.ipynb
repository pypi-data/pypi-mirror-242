# %%
# !pip install -e ~/projects/release_testing/langkit

# %%
# !pip install opentelemetry-api opentelemetry-sdk
# !pip install opentelemetry-instrumentation requests
# !pip install opentelemetry-instrument-openai
# !pip install opentelemetry-exporter-zipkin

# %%
from opentelemetry import trace
from opentelemetry.trace import SpanKind
from opentelemetry.trace.status import Status
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.trace.export import SimpleSpanProcessor
from opentelemetry.sdk.resources import Resource
from opentelemetry.sdk.trace.export import ConsoleSpanExporter

# %%
# try with zipkin as backend / export to zipkin as json
from opentelemetry.sdk.trace.export import BatchSpanProcessor
from opentelemetry.exporter.zipkin.json import ZipkinExporter
from opentelemetry.sdk.resources import SERVICE_NAME, Resource

resource = Resource(attributes={
    SERVICE_NAME: "langkit-otel-test"
})

tracer_provider = TracerProvider(resource=resource)

# Set the tracer provider with the above resource
trace.set_tracer_provider(tracer_provider)

# Create a ZipkinExporter
zipkin_exporter = ZipkinExporter(
    # specify the endpoint where you want to send the traces
    endpoint="http://localhost:9411/api/v2/spans"
)

# Add the exporter to the tracer
trace.get_tracer_provider().add_span_processor(
    BatchSpanProcessor(zipkin_exporter)
)

# %%
tracer = trace.get_tracer("LangKit")

# %%
import whylogs as why

why.init()
text_schema = None

with tracer.start_as_current_span("llm_metrics import"):
    from langkit import llm_metrics # alternatively use 'light_metrics'
    with tracer.start_as_current_span("llm_metrics.init()"):
        text_schema = llm_metrics.init()

# %%
from langkit.whylogs.samples import load_chats, show_first_chat

# Let's look at what's in this toy example:
chats = load_chats()
print(f"There are {len(chats)} records in this toy example data, here's the first one:")
show_first_chat(chats)

with tracer.start_as_current_span("why.log") as why_log_span:
    results = why.log(chats, name="langkit-sample-chats-all", schema=text_schema)
    row_count = len(chats)
    why_log_span.set_attribute("langkit.row_count", row_count)
    metadata = results.metadata
    for key in metadata:
        why_log_span.set_attribute(key, metadata[key])
# Out:
# There are 50 records in this toy example data, here's the first one:
# prompt: Hello, response: World!
# /home/jamie/projects/release_testing/langkit/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /home/jamie/projects/release_testing/langkit/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# ✅ Aggregated 50 rows into profile langkit-sample-chats-all
#
# Visualize and explore this profile with one-click
# 🔍 https://observatory.development.whylabsdev.com/resources/model-1/profiles?profile=ref-xR4e4XCoowjAjq25&sessionToken=session-tnU69Kmt

# %%
import os
os.environ["WHYLABS_API_ENDPOINT"] = "https://songbird.development.whylabsdev.com"
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langkit.config import check_or_prompt_for_api_keys

check_or_prompt_for_api_keys()
# Out:
# WhyLabs Org ID is already set in env var to: org-0
# WhyLabs Dataset ID is already set in env var to: model-2261
# Whylabs API Key already set with ID:  d4YsUS52cZ
# OPENAI_API_KEY already set in env var, good job!

# %%
import importlib
def init_openai_instrumentor(trace_provider):
    if importlib.util.find_spec("openai") is not None:
        from opentelemetry.instrumentation.openai import OpenAIInstrumentor

        instrumentor = OpenAIInstrumentor()
        if not instrumentor.is_instrumented_by_opentelemetry:
            instrumentor.instrument(trace_provider=trace_provider)



init_openai_instrumentor(trace_provider=tracer_provider)

# %%
from langkit.openai.openai import Conversation,OpenAIDefault

llm = Conversation(invocation_params=OpenAIDefault())
results = None
with tracer.start_as_current_span("openai", kind=trace.SpanKind.CONSUMER) as openai_span:
    chat = llm.send_prompt("this is a test, can you give me a random fake US phone number to test the format?")
    print(chat.to_dict())
    with tracer.start_as_current_span("why.log", kind=trace.SpanKind.CONSUMER) as why_log_span:
        trace_id = str(why_log_span.get_span_context().trace_id)
        results = why.log(chat.to_dict(), trace_id=trace_id, schema=text_schema)
        metadata = results.metadata
        for key in metadata:
            why_log_span.set_attribute(key, metadata[key])
        column_profile = results.view().get_column("response.has_patterns")
        fi_metric = column_profile.get_metric('frequent_items')
        why_log_span.set_attribute("response.has_patterns", "Phone Number")
# Out:
# {'prompt': 'this is a test, can you give me a random fake US phone number to test the format?', 'response': "Sure! Here's a random fake US phone number for testing: (555) 123-4567.", 'errors': None, 'total_tokens': 63}
#
# ✅ Aggregated 1 rows into profile
# /home/jamie/projects/release_testing/langkit/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Visualize and explore this profile with one-click
# 🔍 https://observatory.development.whylabsdev.com/resources/model-1/profiles?profile=1700179200000&sessionToken=session-tnU69Kmt

# %%
results.view().to_pandas()
# Out:
#                                       counts/inf  counts/n  counts/nan  \
# column
# errors                                         0         1           0
# prompt                                         0         1           0
# prompt.aggregate_reading_level                 0         1           0
# prompt.automated_readability_index             0         1           0
# prompt.character_count                         0         1           0
# prompt.difficult_words                         0         1           0
# prompt.flesch_reading_ease                     0         1           0
# prompt.has_patterns                            0         1           0
# prompt.jailbreak_similarity                    0         1           0
# prompt.letter_count                            0         1           0
# prompt.lexicon_count                           0         1           0
# prompt.monosyllable_count                      0         1           0
# prompt.polysyllable_count                      0         1           0
# prompt.sentence_count                          0         1           0
# prompt.sentiment_nltk                          0         1           0
# prompt.syllable_count                          0         1           0
# prompt.toxicity                                0         1           0
# response                                       0         1           0
# response.aggregate_reading_level               0         1           0
# response.automated_readability_index           0         1           0
# response.character_count                       0         1           0
# response.difficult_words                       0         1           0
# response.flesch_reading_ease                   0         1           0
# response.has_patterns                          0         1           0
# response.letter_count                          0         1           0
# response.lexicon_count                         0         1           0
# response.monosyllable_count                    0         1           0
# response.polysyllable_count                    0         1           0
# response.refusal_similarity                    0         1           0
# response.relevance_to_prompt                   0         1           0
# response.sentence_count                        0         1           0
# response.sentiment_nltk                        0         1           0
# response.syllable_count                        0         1           0
# response.toxicity                              0         1           0
# total_tokens                                   0         1           0
#
#                                       counts/null                type  \
# column
# errors                                          1  SummaryType.COLUMN
# prompt                                          0  SummaryType.COLUMN
# prompt.aggregate_reading_level                  0  SummaryType.COLUMN
# prompt.automated_readability_index              0  SummaryType.COLUMN
# prompt.character_count                          0  SummaryType.COLUMN
# prompt.difficult_words                          0  SummaryType.COLUMN
# prompt.flesch_reading_ease                      0  SummaryType.COLUMN
# prompt.has_patterns                             1  SummaryType.COLUMN
# prompt.jailbreak_similarity                     0  SummaryType.COLUMN
# prompt.letter_count                             0  SummaryType.COLUMN
# prompt.lexicon_count                            0  SummaryType.COLUMN
# prompt.monosyllable_count                       0  SummaryType.COLUMN
# prompt.polysyllable_count                       0  SummaryType.COLUMN
# prompt.sentence_count                           0  SummaryType.COLUMN
# prompt.sentiment_nltk                           0  SummaryType.COLUMN
# prompt.syllable_count                           0  SummaryType.COLUMN
# prompt.toxicity                                 0  SummaryType.COLUMN
# response                                        0  SummaryType.COLUMN
# response.aggregate_reading_level                0  SummaryType.COLUMN
# response.automated_readability_index            0  SummaryType.COLUMN
# response.character_count                        0  SummaryType.COLUMN
# response.difficult_words                        0  SummaryType.COLUMN
# response.flesch_reading_ease                    0  SummaryType.COLUMN
# response.has_patterns                           0  SummaryType.COLUMN
# response.letter_count                           0  SummaryType.COLUMN
# response.lexicon_count                          0  SummaryType.COLUMN
# response.monosyllable_count                     0  SummaryType.COLUMN
# response.polysyllable_count                     0  SummaryType.COLUMN
# response.refusal_similarity                     0  SummaryType.COLUMN
# response.relevance_to_prompt                    0  SummaryType.COLUMN
# response.sentence_count                         0  SummaryType.COLUMN
# response.sentiment_nltk                         0  SummaryType.COLUMN
# response.syllable_count                         0  SummaryType.COLUMN
# response.toxicity                               0  SummaryType.COLUMN
# total_tokens                                    0  SummaryType.COLUMN
#
#                                       types/boolean  types/fractional  \
# column
# errors                                            0                 0
# prompt                                            0                 0
# prompt.aggregate_reading_level                    0                 1
# prompt.automated_readability_index                0                 1
# prompt.character_count                            0                 0
# prompt.difficult_words                            0                 0
# prompt.flesch_reading_ease                        0                 1
# prompt.has_patterns                               0                 0
# prompt.jailbreak_similarity                       0                 1
# prompt.letter_count                               0                 0
# prompt.lexicon_count                              0                 0
# prompt.monosyllable_count                         0                 0
# prompt.polysyllable_count                         0                 0
# prompt.sentence_count                             0                 0
# prompt.sentiment_nltk                             0                 1
# prompt.syllable_count                             0                 0
# prompt.toxicity                                   0                 1
# response                                          0                 0
# response.aggregate_reading_level                  0                 1
# response.automated_readability_index              0                 1
# response.character_count                          0                 0
# response.difficult_words                          0                 0
# response.flesch_reading_ease                      0                 1
# response.has_patterns                             0                 0
# response.letter_count                             0                 0
# response.lexicon_count                            0                 0
# response.monosyllable_count                       0                 0
# response.polysyllable_count                       0                 0
# response.refusal_similarity                       0                 1
# response.relevance_to_prompt                      0                 1
# response.sentence_count                           0                 0
# response.sentiment_nltk                           0                 1
# response.syllable_count                           0                 0
# response.toxicity                                 0                 1
# total_tokens                                      0                 0
#
#                                       types/integral  types/object  \
# column
# errors                                             0             0
# prompt                                             0             0
# prompt.aggregate_reading_level                     0             0
# prompt.automated_readability_index                 0             0
# prompt.character_count                             1             0
# prompt.difficult_words                             1             0
# prompt.flesch_reading_ease                         0             0
# prompt.has_patterns                                0             0
# prompt.jailbreak_similarity                        0             0
# prompt.letter_count                                1             0
# prompt.lexicon_count                               1             0
# prompt.monosyllable_count                          1             0
# prompt.polysyllable_count                          1             0
# prompt.sentence_count                              1             0
# prompt.sentiment_nltk                              0             0
# prompt.syllable_count                              1             0
# prompt.toxicity                                    0             0
# response                                           0             0
# response.aggregate_reading_level                   0             0
# response.automated_readability_index               0             0
# response.character_count                           1             0
# response.difficult_words                           1             0
# response.flesch_reading_ease                       0             0
# response.has_patterns                              0             0
# response.letter_count                              1             0
# response.lexicon_count                             1             0
# response.monosyllable_count                        1             0
# response.polysyllable_count                        1             0
# response.refusal_similarity                        0             0
# response.relevance_to_prompt                       0             0
# response.sentence_count                            1             0
# response.sentiment_nltk                            0             0
# response.syllable_count                            1             0
# response.toxicity                                  0             0
# total_tokens                                       1             0
#
#                                       types/string  ...  distribution/q_10  \
# column                                              ...
# errors                                           0  ...                NaN
# prompt                                           1  ...                NaN
# prompt.aggregate_reading_level                   0  ...           6.000000
# prompt.automated_readability_index               0  ...           4.300000
# prompt.character_count                           0  ...          64.000000
# prompt.difficult_words                           0  ...           2.000000
# prompt.flesch_reading_ease                       0  ...          87.050000
# prompt.has_patterns                              0  ...                NaN
# prompt.jailbreak_similarity                      0  ...           0.278322
# prompt.letter_count                              0  ...          62.000000
# prompt.lexicon_count                             0  ...          18.000000
# prompt.monosyllable_count                        0  ...          15.000000
# prompt.polysyllable_count                        0  ...           0.000000
# prompt.sentence_count                            0  ...           1.000000
# prompt.sentiment_nltk                            0  ...          -0.421500
# prompt.syllable_count                            0  ...          21.000000
# prompt.toxicity                                  0  ...           0.001950
# response                                         1  ...                NaN
# response.aggregate_reading_level                 0  ...           4.000000
# response.automated_readability_index             0  ...           7.100000
# response.character_count                         0  ...          50.000000
# response.difficult_words                         0  ...           1.000000
# response.flesch_reading_ease                     0  ...          95.170000
# response.has_patterns                            1  ...                NaN
# response.letter_count                            0  ...          43.000000
# response.lexicon_count                           0  ...          10.000000
# response.monosyllable_count                      0  ...           8.000000
# response.polysyllable_count                      0  ...           0.000000
# response.refusal_similarity                      0  ...           0.158402
# response.relevance_to_prompt                     0  ...           0.751508
# response.sentence_count                          0  ...           1.000000
# response.sentiment_nltk                          0  ...          -0.200300
# response.syllable_count                          0  ...          12.000000
# response.toxicity                                0  ...           0.002532
# total_tokens                                     0  ...          61.000000
#
#                                       distribution/q_25  distribution/q_75  \
# column
# errors                                              NaN                NaN
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 6.000000           6.000000
# prompt.automated_readability_index             4.300000           4.300000
# prompt.character_count                        64.000000          64.000000
# prompt.difficult_words                         2.000000           2.000000
# prompt.flesch_reading_ease                    87.050000          87.050000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.278322           0.278322
# prompt.letter_count                           62.000000          62.000000
# prompt.lexicon_count                          18.000000          18.000000
# prompt.monosyllable_count                     15.000000          15.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                         -0.421500          -0.421500
# prompt.syllable_count                         21.000000          21.000000
# prompt.toxicity                                0.001950           0.001950
# response                                            NaN                NaN
# response.aggregate_reading_level               4.000000           4.000000
# response.automated_readability_index           7.100000           7.100000
# response.character_count                      50.000000          50.000000
# response.difficult_words                       1.000000           1.000000
# response.flesch_reading_ease                  95.170000          95.170000
# response.has_patterns                               NaN                NaN
# response.letter_count                         43.000000          43.000000
# response.lexicon_count                        10.000000          10.000000
# response.monosyllable_count                    8.000000           8.000000
# response.polysyllable_count                    0.000000           0.000000
# response.refusal_similarity                    0.158402           0.158402
# response.relevance_to_prompt                   0.751508           0.751508
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                       -0.200300          -0.200300
# response.syllable_count                       12.000000          12.000000
# response.toxicity                              0.002532           0.002532
# total_tokens                                  61.000000          61.000000
#
#                                       distribution/q_90  distribution/q_95  \
# column
# errors                                              NaN                NaN
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 6.000000           6.000000
# prompt.automated_readability_index             4.300000           4.300000
# prompt.character_count                        64.000000          64.000000
# prompt.difficult_words                         2.000000           2.000000
# prompt.flesch_reading_ease                    87.050000          87.050000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.278322           0.278322
# prompt.letter_count                           62.000000          62.000000
# prompt.lexicon_count                          18.000000          18.000000
# prompt.monosyllable_count                     15.000000          15.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                         -0.421500          -0.421500
# prompt.syllable_count                         21.000000          21.000000
# prompt.toxicity                                0.001950           0.001950
# response                                            NaN                NaN
# response.aggregate_reading_level               4.000000           4.000000
# response.automated_readability_index           7.100000           7.100000
# response.character_count                      50.000000          50.000000
# response.difficult_words                       1.000000           1.000000
# response.flesch_reading_ease                  95.170000          95.170000
# response.has_patterns                               NaN                NaN
# response.letter_count                         43.000000          43.000000
# response.lexicon_count                        10.000000          10.000000
# response.monosyllable_count                    8.000000           8.000000
# response.polysyllable_count                    0.000000           0.000000
# response.refusal_similarity                    0.158402           0.158402
# response.relevance_to_prompt                   0.751508           0.751508
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                       -0.200300          -0.200300
# response.syllable_count                       12.000000          12.000000
# response.toxicity                              0.002532           0.002532
# total_tokens                                  61.000000          61.000000
#
#                                       distribution/q_99  distribution/stddev  \
# column
# errors                                              NaN                  NaN
# prompt                                              NaN                  0.0
# prompt.aggregate_reading_level                 6.000000                  0.0
# prompt.automated_readability_index             4.300000                  0.0
# prompt.character_count                        64.000000                  0.0
# prompt.difficult_words                         2.000000                  0.0
# prompt.flesch_reading_ease                    87.050000                  0.0
# prompt.has_patterns                                 NaN                  0.0
# prompt.jailbreak_similarity                    0.278322                  0.0
# prompt.letter_count                           62.000000                  0.0
# prompt.lexicon_count                          18.000000                  0.0
# prompt.monosyllable_count                     15.000000                  0.0
# prompt.polysyllable_count                      0.000000                  0.0
# prompt.sentence_count                          1.000000                  0.0
# prompt.sentiment_nltk                         -0.421500                  0.0
# prompt.syllable_count                         21.000000                  0.0
# prompt.toxicity                                0.001950                  0.0
# response                                            NaN                  0.0
# response.aggregate_reading_level               4.000000                  0.0
# response.automated_readability_index           7.100000                  0.0
# response.character_count                      50.000000                  0.0
# response.difficult_words                       1.000000                  0.0
# response.flesch_reading_ease                  95.170000                  0.0
# response.has_patterns                               NaN                  0.0
# response.letter_count                         43.000000                  0.0
# response.lexicon_count                        10.000000                  0.0
# response.monosyllable_count                    8.000000                  0.0
# response.polysyllable_count                    0.000000                  0.0
# response.refusal_similarity                    0.158402                  0.0
# response.relevance_to_prompt                   0.751508                  0.0
# response.sentence_count                        1.000000                  0.0
# response.sentiment_nltk                       -0.200300                  0.0
# response.syllable_count                       12.000000                  0.0
# response.toxicity                              0.002532                  0.0
# total_tokens                                  61.000000                  0.0
#
#                                       ints/max  ints/min  \
# column
# errors                                     NaN       NaN
# prompt                                     NaN       NaN
# prompt.aggregate_reading_level             NaN       NaN
# prompt.automated_readability_index         NaN       NaN
# prompt.character_count                    64.0      64.0
# prompt.difficult_words                     2.0       2.0
# prompt.flesch_reading_ease                 NaN       NaN
# prompt.has_patterns                        NaN       NaN
# prompt.jailbreak_similarity                NaN       NaN
# prompt.letter_count                       62.0      62.0
# prompt.lexicon_count                      18.0      18.0
# prompt.monosyllable_count                 15.0      15.0
# prompt.polysyllable_count                  0.0       0.0
# prompt.sentence_count                      1.0       1.0
# prompt.sentiment_nltk                      NaN       NaN
# prompt.syllable_count                     21.0      21.0
# prompt.toxicity                            NaN       NaN
# response                                   NaN       NaN
# response.aggregate_reading_level           NaN       NaN
# response.automated_readability_index       NaN       NaN
# response.character_count                  50.0      50.0
# response.difficult_words                   1.0       1.0
# response.flesch_reading_ease               NaN       NaN
# response.has_patterns                      NaN       NaN
# response.letter_count                     43.0      43.0
# response.lexicon_count                    10.0      10.0
# response.monosyllable_count                8.0       8.0
# response.polysyllable_count                0.0       0.0
# response.refusal_similarity                NaN       NaN
# response.relevance_to_prompt               NaN       NaN
# response.sentence_count                    1.0       1.0
# response.sentiment_nltk                    NaN       NaN
# response.syllable_count                   12.0      12.0
# response.toxicity                          NaN       NaN
# total_tokens                              61.0      61.0
#
#                                                         frequent_items/frequent_strings
# column
# errors                                                                              NaN
# prompt                                                                              NaN
# prompt.aggregate_reading_level                                                      NaN
# prompt.automated_readability_index                                                  NaN
# prompt.character_count                                                              NaN
# prompt.difficult_words                                                              NaN
# prompt.flesch_reading_ease                                                          NaN
# prompt.has_patterns                                                                  []
# prompt.jailbreak_similarity                                                         NaN
# prompt.letter_count                                                                 NaN
# prompt.lexicon_count                                                                NaN
# prompt.monosyllable_count                                                           NaN
# prompt.polysyllable_count                                                           NaN
# prompt.sentence_count                                                               NaN
# prompt.sentiment_nltk                                                               NaN
# prompt.syllable_count                                                               NaN
# prompt.toxicity                                                                     NaN
# response                                                                            NaN
# response.aggregate_reading_level                                                    NaN
# response.automated_readability_index                                                NaN
# response.character_count                                                            NaN
# response.difficult_words                                                            NaN
# response.flesch_reading_ease                                                        NaN
# response.has_patterns                 [FrequentItem(value='phone number', est=1, upp...
# response.letter_count                                                               NaN
# response.lexicon_count                                                              NaN
# response.monosyllable_count                                                         NaN
# response.polysyllable_count                                                         NaN
# response.refusal_similarity                                                         NaN
# response.relevance_to_prompt                                                        NaN
# response.sentence_count                                                             NaN
# response.sentiment_nltk                                                             NaN
# response.syllable_count                                                             NaN
# response.toxicity                                                                   NaN
# total_tokens                                                                        NaN
#
# [35 rows x 31 columns]
